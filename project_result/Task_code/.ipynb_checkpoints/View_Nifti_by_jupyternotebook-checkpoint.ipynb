# %%
# !pip install nilearn
# !pip install SimpleITK
import nibabel as nib
import matplotlib.pyplot as plt
from nilearn.plotting import view_img, plot_glass_brain, plot_anat, plot_epi
import os
from glob import glob
import SimpleITK as sitk
import numpy as np

# %% [markdown]
# 필요한거 cmd들어가서
#
# pip install --- 하면 돼요,
#
# (모르면 인터넷 검색,,,,)

# %% [markdown]
# ==============================

# %% [markdown]
# 1)
# #경로 넣고 (C:/Desktop:/ )=>이런형식
#
# image = 'first_pancreas_data/prep_exports/4203705.nii'

# %%
image = 'C:\\Users\\pks98\\Desktop\\project_result\\167043_T1.nii.gz'
Nifti = nib.load(image)
plot_anat(Nifti, display_mode='z')
## nii.gz.도 읽어오고 nii도 읽어옴

# %%
plot_anat(Nifti, display_mode='x')

# %% [markdown]
# 2)

# %%
image = 'C:\\Users\\pks98\\Desktop\\project_result\\167043_T1.nii.gz'
image_1 = sitk.ReadImage(image)
plt.imshow(sitk.GetArrayFromImage(image_1)[150,:,:,], cmap="gray")
plt.show()
## z축으로 층층이 몇장인지 보고 그 범위 내에서 입력해야함
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-bb18e52dfacd> in <module>
#       1 image = 'C:\\Users\\pks98\\Desktop\\project_result\\167043_T1.nii.gz'
#       2 image_1 = sitk.ReadImage(image)
# ----> 3 plt.imshow(sitk.GetArrayFromImage(image_1)[150,:,:,], cmap="gray")
#       4 plt.show()
#
# IndexError: index 150 is out of bounds for axis 0 with size 21

# %%
image = 'C:\\Users\\pks98\\Desktop\\project_result\\167043_T1.nii.gz'
image_1 = sitk.ReadImage(image)
plt.imshow(sitk.GetArrayFromImage(image_1)[10,:,:,], cmap="gray")
plt.show()

# %% [markdown]
# 150 저 숫자 바꾸면 다른 것도 볼 수 있긴해여,,,
#
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
#
# 코딩의 세계에 오신걸 환영합니다

# %%
image = 'C:\\Users\\pks98\\Desktop\\project_result\\167043_T1.nii.gz'
image_1 = sitk.ReadImage(image)
plt.imshow(sitk.GetArrayFromImage(image_1)[10,:50,:,], cmap="gray")
plt.show()

# %%
image = 'C:\\Users\\pks98\\Desktop\\project_result\\167043_T1.nii.gz'
image_1 = sitk.ReadImage(image)
plt.imshow(sitk.GetArrayFromImage(image_1)[10,:,:100], cmap="gray")
plt.show()

# %% [markdown]
# simpleITK는 [z, y, x] 이렇게 불러오는건가..?
